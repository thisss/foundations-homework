# %% [markdown]
# # All these sick animals

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Open your dataset up using pandas in a Jupyter notebook

# %% [markdown]
# Switzerland does [publish statistics](https://www.infosm.blv.admin.ch/public/) about deseases by animals. I downloaded the statistics for the canton of Bern. Since the file was encoded in ISO-8859 I had to convert it to UTF8 using the following linux command: iconv-f ISO-8859-1 infile.csv -t UTF8 -o outfile.csv.

# %%
df = pd.read_csv("sickanimals.csv", sep=";", header=0)

# %% [markdown]
# ## Do a .head() to get a feel for your data

# %%
df.head()
# Out:
#   diagnosedatum kanton         bezirk    gemeinde            seuchengruppe  \
# 0    01.12.2006   Bern  Schwarzenburg    Albligen   Zu bekämpfende Seuchen
# 1    12.12.2006   Bern       Burgdorf  Kernenried    Auszurottende Seuchen
# 2    12.12.2006   Bern   Trachselwald     Rüegsau    Auszurottende Seuchen
# 3    13.12.2006   Bern     Courtelary  Courtelary  Zu überwachende Seuchen
# 4    07.12.2006   Bern   Trachselwald   Sumiswald  Zu überwachende Seuchen
#
#                                           tierseuche tierart tierkategorie  \
# 0               Schafräude (2009 aus TSV gestrichen)   Schaf           NaN
# 1  Bovine Virus Diarrhoe / Mucosal Disease (BVD /...    Rind           NaN
# 2  Bovine Virus Diarrhoe / Mucosal Disease (BVD /...    Rind           NaN
# 3                                   Kryptosporidiose    Rind           NaN
# 4                                   Kryptosporidiose    Rind           NaN
#
#    anzahlinfizierterfaelle  anzahlgetoetefaelle
# 0                        0                    0
# 1                        1                    0
# 2                        1                    0
# 3                        1                    0
# 4                        1                    0

# %% [markdown]
# ## Write down 12 questions to ask your data, or 12 things to hunt for in the data.

# %% [markdown]
# - How many entries in total?
# - How many entries per year?
# - What municipality has the most entries?
# - What municipality had the most infected animals?
# - In what municipality were the most animals killed?
# - What year was bad?
# - How many cases per species?

# %% [markdown]
# ## What diseases affected the highest number of animals?

# %%
df.sort_values('anzahlinfizierterfaelle', ascending = False).head(10)
# Out:
#      diagnosedatum kanton         bezirk               gemeinde  \
# 471     21.12.2000   Bern   Trachselwald  Affoltern im Emmental
# 293     16.12.2002   Bern      Oberhasli                 Gadmen
# 4445    11.12.2003   Bern        Aarberg        Rapperswil (BE)
# 2537    27.04.2008   Bern          Nidau                  Twann
# 812     27.09.2001   Bern  La Neuveville               Lamboing
#
#                seuchengruppe  \
# 471   Zu bekämpfende Seuchen
# 293   Zu bekämpfende Seuchen
# 4445  Zu bekämpfende Seuchen
# 2537  Zu bekämpfende Seuchen
# 812   Zu bekämpfende Seuchen
#
#                                              tierseuche  tierart  \
# 471   Salmonella-Enteritidis-Infektion der Hühner (b...     Huhn
# 293                Schafräude (2009 aus TSV gestrichen)    Schaf
# 4445                 Enzootische Pneumonie der Schweine  Schwein
# 2537                               Sauerbrut der Bienen   Bienen
# 812                                 Faulbrut der Bienen   Bienen
#
#      tierkategorie  anzahlinfizierterfaelle  anzahlgetoetefaelle
# 471            NaN                      760                  760
# 293            NaN                       70                    0
# 4445           NaN                       60                   60
# 2537           NaN                       54                    0
# 812            NaN                       34                    0

# %% [markdown]
# ## How many animals were killed all together?

# %%
df['anzahlgetoetefaelle'].sum()
# Out:
# 11712

# %% [markdown]
# ## What were the most lethal incidies?

# %%
df.sort_values('anzahlgetoetefaelle', ascending=False).head()
# Out:
#      diagnosedatum kanton                bezirk               gemeinde  \
# 7480    27.01.2016   Bern                Erlach                    Ins
# 8135    12.01.2016   Bern  Interlaken-Oberhasli              Meiringen
# 326     25.08.2000   Bern                 Büren                  Wengi
# 471     21.12.2000   Bern          Trachselwald  Affoltern im Emmental
# 739     15.06.1993   Bern                Signau                    NaN
#
#                 seuchengruppe  \
# 7480   Zu bekämpfende Seuchen
# 8135   Zu bekämpfende Seuchen
# 326    Zu bekämpfende Seuchen
# 471    Zu bekämpfende Seuchen
# 739   Hochansteckende Seuchen
#
#                                              tierseuche  tierart  \
# 7480  Salmonella-Infektion des Geflügels und der Sch...     Huhn
# 8135  Salmonella-Infektion des Geflügels und der Sch...     Huhn
# 326   Salmonella-Enteritidis-Infektion der Hühner (b...     Huhn
# 471   Salmonella-Enteritidis-Infektion der Hühner (b...     Huhn
# 739                             Klassische Schweinepest  Schwein
#
#      tierkategorie  anzahlinfizierterfaelle  anzahlgetoetefaelle
# 7480           NaN                        1                 4900
# 8135     Legehenne                        1                 3000
# 326            NaN                        0                 2000
# 471            NaN                      760                  760
# 739            NaN                        0                  400

# %% [markdown]
# ## Show me the highly transferable for each kind of animal.

# %%
df[df['seuchengruppe'] == 'Hochansteckende Seuchen'].sort_values('tierart')
# Out:
#      diagnosedatum kanton           bezirk             gemeinde  \
# 685     15.12.1995   Bern            Nidau                  NaN
# 4524    15.11.1992   Bern            Nidau            Täuffelen
# 7753    15.08.1995   Bern         Burgdorf                  NaN
# 7761    15.03.1994   Bern        Oberhasli                  NaN
# 739     15.06.1993   Bern           Signau                  NaN
# 740     15.12.1993   Bern         Burgdorf                  NaN
# 7854    15.10.1993   Bern             Bern                  NaN
# 621     15.01.1996   Bern            Büren  Diessbach bei Büren
# 622     15.01.1996   Bern      Konolfingen                  NaN
# 2959    08.10.2009   Bern  Thun (bis 2010)            Sigriswil
# 8026    15.11.1991   Bern        Aarwangen                  NaN
#
#                 seuchengruppe               tierseuche  tierart tierkategorie  \
# 685   Hochansteckende Seuchen      Newcastle Krankheit     Huhn           NaN
# 4524  Hochansteckende Seuchen      Newcastle Krankheit     Huhn           NaN
# 7753  Hochansteckende Seuchen      Newcastle Krankheit     Huhn           NaN
# 7761  Hochansteckende Seuchen      Newcastle Krankheit     Huhn           NaN
# 739   Hochansteckende Seuchen  Klassische Schweinepest  Schwein           NaN
# 740   Hochansteckende Seuchen  Klassische Schweinepest  Schwein           NaN
# 7854  Hochansteckende Seuchen  Klassische Schweinepest  Schwein           NaN
# 621   Hochansteckende Seuchen      Newcastle Krankheit    Taube           NaN
# 622   Hochansteckende Seuchen      Newcastle Krankheit    Taube           NaN
# 2959  Hochansteckende Seuchen      Newcastle Krankheit    Taube           NaN
# 8026  Hochansteckende Seuchen      Newcastle Krankheit    Taube           NaN
#
#       anzahlinfizierterfaelle  anzahlgetoetefaelle
# 685                         0                    0
# 4524                        1                    0
# 7753                        0                    0
# 7761                        0                    0
# 739                         0                  400
# 740                         0                  174
# 7854                        0                   89
# 621                         0                    0
# 622                         0                    0
# 2959                        2                    0
# 8026                        0                    0

# %% [markdown]
# ## In what villages and towns did most incidents happen?

# %%
df['gemeinde'].value_counts().head(15)
# Out:
# Sumiswald                146
# Langnau im Emmental      145
# Frutigen                 113
# Köniz                    112
# Wahlern                  110
# Buchholterberg           110
# Lützelflüh               108
# Rüeggisberg               93
# Huttwil                   92
# Rüderswil                 89
# Worb                      88
# Rüegsau                   88
# Hasle bei Burgdorf        87
# Wynigen                   85
# Affoltern im Emmental     81
# Name: gemeinde, dtype: int64

# %% [markdown]
# ## What incidents occured in the town Aarberg?

# %%
df[df['gemeinde'] == 'Aarberg']
# Out:
#      diagnosedatum kanton   bezirk gemeinde           seuchengruppe  \
# 1221    02.06.2004   Bern  Aarberg  Aarberg  Zu bekämpfende Seuchen
# 1604    10.09.2005   Bern  Aarberg  Aarberg  Zu bekämpfende Seuchen
# 5036    10.10.2008   Bern  Aarberg  Aarberg   Auszurottende Seuchen
# 5095    20.10.2008   Bern  Aarberg  Aarberg   Auszurottende Seuchen
# 5419    27.11.2008   Bern  Aarberg  Aarberg   Auszurottende Seuchen
#
#                                              tierseuche tierart tierkategorie  \
# 1221                               Sauerbrut der Bienen  Bienen           NaN
# 1604                               Sauerbrut der Bienen  Bienen           NaN
# 5036  Bovine Virus Diarrhoe / Mucosal Disease (BVD /...    Rind           NaN
# 5095  Bovine Virus Diarrhoe / Mucosal Disease (BVD /...    Rind           NaN
# 5419  Bovine Virus Diarrhoe / Mucosal Disease (BVD /...    Rind           NaN
#
#       anzahlinfizierterfaelle  anzahlgetoetefaelle
# 1221                        3                    0
# 1604                        1                    0
# 5036                        1                    0
# 5095                        3                    0
# 5419                        1                    0

# %% [markdown]
# ## What animals are the sickest?

# %%
df['tierart'].value_counts()
# Out:
# Rind                 3487
# Bienen               3448
# Ziege                 373
# Schaf                 237
# Schwein               125
# Hund                  101
# Kaninchen              82
# Huhn                   64
# Fisch                  49
# Fuchs                  47
# Taube                  20
# Luchs                  17
# Katze                  17
# Papagei                16
# Schlange               10
# Pferd                   9
# Hase                    8
# anderes Haustier        6
# Hirsch                  5
# Marder                  4
# Echse                   3
# Sittich                 3
# Affe                    2
# anderer Wildvogel       2
# anderes Wildtier        2
# anderes Zootier         1
# Wolf                    1
# Dachs                   1
# Wildschwein             1
# Name: tierart, dtype: int64

# %% [markdown]
# ##  Show all the "Kryptosporidiose" cases in the municipality Courtelary.

# %%
df[(df['tierseuche'] == "Kryptosporidiose") & (df['bezirk'] == 'Courtelary')]
# Out:
#      diagnosedatum kanton      bezirk           gemeinde  \
# 3       13.12.2006   Bern  Courtelary         Courtelary
# 13      21.03.2007   Bern  Courtelary          Corgémont
# 132     19.02.2007   Bern  Courtelary           Tramelan
# 137     27.02.2007   Bern  Courtelary         Courtelary
# 143     19.02.2007   Bern  Courtelary         Courtelary
# 2210    18.06.2007   Bern  Courtelary         Courtelary
# 2365    11.10.2007   Bern  Courtelary        La Ferrière
# 2430    05.12.2007   Bern  Courtelary           Cormoret
# 2472    08.01.2008   Bern  Courtelary  Sonceboz-Sombeval
# 2486    21.01.2008   Bern  Courtelary          Corgémont
# 2979    19.04.2010   Bern  Courtelary          Sonvilier
#
#                 seuchengruppe        tierseuche tierart tierkategorie  \
# 3     Zu überwachende Seuchen  Kryptosporidiose    Rind           NaN
# 13    Zu überwachende Seuchen  Kryptosporidiose    Rind           NaN
# 132   Zu überwachende Seuchen  Kryptosporidiose    Rind           NaN
# 137   Zu überwachende Seuchen  Kryptosporidiose    Rind           NaN
# 143   Zu überwachende Seuchen  Kryptosporidiose    Rind           NaN
# 2210  Zu überwachende Seuchen  Kryptosporidiose    Rind           NaN
# 2365  Zu überwachende Seuchen  Kryptosporidiose    Rind           NaN
# 2430  Zu überwachende Seuchen  Kryptosporidiose    Rind           NaN
# 2472  Zu überwachende Seuchen  Kryptosporidiose    Rind           NaN
# 2486  Zu überwachende Seuchen  Kryptosporidiose    Rind           NaN
# 2979  Zu überwachende Seuchen  Kryptosporidiose    Rind           NaN
#
#       anzahlinfizierterfaelle  anzahlgetoetefaelle
# 3                           1                    0
# 13                          1                    0
# 132                         1                    0
# 137                         1                    0
# 143                         1                    0
# 2210                        1                    0
# 2365                        1                    0
# 2430                        1                    0
# 2472                        1                    0
# 2486                        1                    0
# 2979                        1                    0

# %% [markdown]
# ## Make three charts with your dataset

# %%
plt.style.use('seaborn-deep')
df.plot(kind='barh', x='tierseuche', y='anzahlinfizierterfaelle')
