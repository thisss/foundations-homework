# %% [markdown]
# # Homework 7 -- research part
# Answer your own selection out of the following questions, or any other questions you might be able to think of. Write the question down first in a markdown cell (use a # to make the question a nice header), THEN try to get an answer to it. A lot of these are remarkably similar, and some you'll need to do manual work for - the GDP ones, for example.
#
# If you are trying to figure out some other question that we didn't cover in class and it does not have to do with joining to another data set, we're happy to help you figure it out during lab!
#
# Take a peek at the billionaires notebook I uploaded into Slack, it should be helpful for the graphs (I added a few other styles and options, too). You'll probably also want to look at the "sum()" line I added.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_excel('richpeople.xlsx')
rich = data[data['year'] == 2014]

# %% [markdown]
# ## What country are most billionaires from?

# %%
rich['countrycode'].value_counts().head(15)
# Out:
# USA       499
# CHN       152
# RUS       111
# DEU        85
# BRA        65
# IND        56
# GBR        47
# HKG        45
# FRA        43
# ITA        35
# CAN        32
# AUS        29
# Taiwan     28
# JPN        27
# KOR        27
# Name: countrycode, dtype: int64

# %% [markdown]
# ## Who are the top 10 richest billionaires?

# %%
rich.sort_values(by='networthusbillion', ascending=False).head(10)
# Out:
#       year              name  rank    citizenship countrycode  \
# 284   2014        Bill Gates     1  United States         USA
# 348   2014  Carlos Slim Helu     2         Mexico         MEX
# 124   2014    Amancio Ortega     3          Spain         ESP
# 2491  2014    Warren Buffett     4  United States         USA
# 1377  2014     Larry Ellison     5  United States         USA
# 509   2014        David Koch     6  United States         USA
# 381   2014      Charles Koch     6  United States         USA
# 2185  2014   Sheldon Adelson     8  United States         USA
# 429   2014    Christy Walton     9  United States         USA
# 1128  2014        Jim Walton    10  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 284                76.0  self-made       founder non-finance    male  58.0
# 348                72.0  self-made  privatized and resources    male  74.0
# ...

# %% [markdown]
# ## Who are the "poorest" billionaires?

# %%
poorest[poorest['networthusbillion'] == 1.0]
# Out:
#       year                      name  rank     citizenship countrycode  \
# 234   2014               B.R. Shetty  1565           India         IND
# 2092  2014              Rostam Azizi  1565        Tanzania         TZA
# 2401  2014                Tory Burch  1565   United States         USA
# 734   2014                Fred Chang  1565   United States         USA
# 171   2014            Angela Bennett  1565       Australia         AUS
# 748   2014                   Fu Kwan  1565           China         CHN
# 2107  2014            Ryan Kavanaugh  1565   United States         USA
# 1783  2014         O. Francis Biondi  1565   United States         USA
# 1371  2014              Lam Fong Ngo  1565           Macau         MAC
# 702   2014             Feng Hailiang  1565           China         CHN
# 2484  2014                 Wang Yong  1565           China         CHN
# 2147  2014              Sara Blakely  1565   United States         USA
# ...

# %% [markdown]
# ## What's the average wealth of a billionaire? Male? Female?

# %%
males = rich[rich['gender'] == 'male']
females = rich[rich['gender'] == 'female']

print("The males own", males['networthusbillion'].mean(), "billion dollar in average.")
print("The females own", females['networthusbillion'].mean(), "billion dollar in average.")
# Out:
# The males own 3.9027155465 billion dollar in average.
# The females own 3.92055555556 billion dollar in average.

# %% [markdown]
# ## How many self made billionaires vs. others?

# %%
rich['selfmade'].value_counts()
# Out:
# self-made    1146
# inherited     505
# Name: selfmade, dtype: int64

# %% [markdown]
# ## How old are billionaires?

# %%
print("The youngest listed Billionaire", int(rich['age'].min()), "years old.")
print("The oldest listed Billionaire is", int(rich['age'].max()), "years old.")
print("But that doesn't mean much. More important is the mean:", int(rich['age'].mean()), "years.")
print("The median lies at", str(rich['age'].median()) + ". If we are lucky, we'll get a nice bell-shaped curve.")
rich['age'].hist(bins=30)
print("\nAnd if you are into statistics -- here are the details:")
print(rich['age'].describe())
# Out:
# The youngest listed Billionaire 24 years old.
# The oldest listed Billionaire is 98 years old.
# But that doesn't mean much. More important is the mean: 63 years.
# The median lies at 63.0. If we are lucky, we'll get a nice bell-shaped curve.
#
# And if you are into statistics -- here are the details:
# count    1590.000000
# mean       63.342138
# std        13.137743
# min        24.000000
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max        98.000000
# Name: age, dtype: float64
# /usr/lib/python3/dist-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)

# %% [markdown]
# ## What's the average wealth of a billionaire? Male? Female?

# %%
print("The average wealth of billionaires is", rich['networthusbillion'].mean(), "billion US dollar (for more information, please see below).\n")
print(rich['networthusbillion'].describe())
print("The average wealth of male billionaires is", males['networthusbillion'].mean(), "billion US dollar (for more information, please see below).\n")
print(males['networthusbillion'].describe())
print("The average wealth of male billionaires is", females['networthusbillion'].mean(), "billion US dollar (for more information, please see below).\n")
print(males['networthusbillion'].describe())
# Out:
# The average wealth of billionaires is 3.90465819722 billion US dollar (for more information, please see below).
#
# count    1653.000000
# mean        3.904658
# std         5.748520
# min         1.000000
# 25%         1.400000
# 50%         2.100000
# 75%         3.700000
# max        76.000000
# Name: networthusbillion, dtype: float64
# The average wealth of male billionaires is 3.9027155465 billion US dollar (for more information, please see below).
#
# count    1473.000000
# mean        3.902716
# std         5.801227
# min         1.000000
# 25%         1.400000
# 50%         2.100000
# 75%         3.700000
# max        76.000000
# Name: networthusbillion, dtype: float64
# The average wealth of male billionaires is 3.92055555556 billion US dollar (for more information, please see below).
#
# count    1473.000000
# mean        3.902716
# std         5.801227
# min         1.000000
# 25%         1.400000
# 50%         2.100000
# 75%         3.700000
# max        76.000000
# ...

# %% [markdown]
# ## Who are the youngest billionaire?

# %%
rich.sort(['age'], ascending=[True]).head()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#       year                 name  rank    citizenship countrycode  \
# 1838  2014          Perenna Kei  1284      Hong Kong         HKG
# 605   2014     Dustin Moskovitz   202  United States         USA
# 1586  2014      Mark Zuckerberg    21  United States         USA
# 189   2014  Anton Kathrein, Jr.  1270        Germany         DEU
# 602   2014         Drew Houston  1372  United States         USA
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 1838                1.3  inherited            inherited  female  24.0
# 605                 6.8  self-made  founder non-finance    male  29.0
# 1586               28.5  self-made  founder non-finance    male  29.0
# 189                 1.4  inherited            inherited    male  29.0
# ...

# %% [markdown]
# ## Most common source of wealth? Male vs. female?

# %% [markdown]
# ## Most common source of wealth? Male vs. female

# %% [markdown]
# ## Who are the oldest billionaires?

# %% [markdown]
# How old are billionaires self made vs. non self made? or different industries?

# %%
rich.groupby('selfmade')['age'].describe()
# Out:
# /usr/lib/python3/dist-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# selfmade
# inherited  count     476.000000
#            mean       64.962185
#            std        13.174403
#            min        24.000000
#            25%              NaN
#            50%              NaN
#            75%              NaN
#            max        98.000000
# self-made  count    1112.000000
#            mean       62.625899
#            std        13.054631
#            min        29.000000
#            25%              NaN
#            50%              NaN
#            75%              NaN
#            max        96.000000
# Name: age, dtype: float64

# %%
rich.groupby('industry')['age'].describe()
# Out:
# /usr/lib/python3/dist-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# industry
# 0                      count      5.000000
#                        mean      63.600000
#                        std       14.170392
#                        min       49.000000
#                        25%             NaN
#                        50%             NaN
#                        75%             NaN
#                        max       85.000000
# Constrution            count     58.000000
#                        mean      64.965517
#                        std       14.234829
#                        min       33.000000
#                        25%             NaN
#                        50%             NaN
#                        75%             NaN
#                        max       92.000000
# Consumer               count    276.000000
#                        mean      64.735507
# ...

# %% [markdown]
# ## For the top ones, how many billionaires per billion people?
# To answer this question, we need to import population data for the different countries. I am using a json dataset on github.

# %%
import requests
response = requests.get('https://raw.githubusercontent.com/samayo/country-data/master/src/country-population.json')
pop_countries = response.json()

pop_countries[0]['country']
rich['citizenship']
# Out:
# 1              United States
# 5       United Arab Emirates
# 6       United Arab Emirates
# 8               Saudi Arabia
# 9                    Nigeria
# 12             United States
# 15                    Brazil
# 17                 Indonesia
# 18                     India
# 23             United States
# 25                    Turkey
# 26                    Turkey
# 27                    Turkey
# 28                    Russia
# 29                     India
# 30                     India
# 34                     Japan
# 37                     Japan
# 38                    Canada
# 39                    France
# 40                    France
# 43                    France
# 45             United States
# 46            United Kingdom
# 47                 Australia
# 48                   Belgium
# 50                   Belgium
# 51                    Russia
# 54                   Germany
# 55                 Hong Kong
#                 ...
# 2584                  Russia
# ...

# %% [markdown]
# ## Own Dataset

# %% [markdown]
# Switzerland has a lot of programs to generate intersting data. Unfortunately, most of this data is only published in monthly or yearly reports without the raw data (for example in the case of the road trafic counts). There's much work to do...
#
# Finally, I selected a dataset about tourism in the canton of Bern. I converted it to UTF8 using the following command:
#
# iconv -f ISO-8859-1 tourism_bern.csv -t UTF8 -o tourism_bern_UTF8.csv

# %%
tourism = pd.read_csv("tourism_bern_UTF8.csv", sep=";", header=1)

# %%
tourism
# Out:
#     Jahr      Monat        Kanton  Schweiz Logiernächte  \
# 0   2010     Januar  Bern / Berne                193693
# 1   2010    Februar  Bern / Berne                224874
# 2   2010       März  Bern / Berne                191835
# 3   2010      April  Bern / Berne                133085
# 4   2010        Mai  Bern / Berne                160063
# 5   2010       Juni  Bern / Berne                204195
# 6   2010       Juli  Bern / Berne                249876
# 7   2010     August  Bern / Berne                241820
# 8   2010  September  Bern / Berne                228728
# 9   2010    Oktober  Bern / Berne                194992
# 10  2010   November  Bern / Berne                114532
# 11  2010   Dezember  Bern / Berne                141928
# 12  2011     Januar  Bern / Berne                202426
# 13  2011    Februar  Bern / Berne                202791
# 14  2011       März  Bern / Berne                192019
# 15  2011      April  Bern / Berne                140187
# ...

# %% [markdown]
# ## Questions
# 'What is relationship to company'? And what are the most common relationships?
# Given the richest person in a country, what % of the GDP is their wealth?
# Add up the wealth of all of the billionaires in a given country (or a few countries) and then compare it to the GDP of the country, or other billionaires, so like pit the US vs India
# What are the most common industries for billionaires to come from? What's the total amount of billionaire money from each industry?
#
# Maybe just made a graph about how wealthy they are in general?
# Maybe plot their net worth vs age (scatterplot)
# Make a bar graph of the top 10 or 20 richest
