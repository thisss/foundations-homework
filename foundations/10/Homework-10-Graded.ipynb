# %% [markdown]
# Graded = 10/10

# %%
import requests
response = requests.get('https://api.forecast.io/forecast/cb31c6739ae1c7377aa0c3bbc1aa9b30/40.80566,-73.96115')
forecast = response.json()

def temp_feeling(day_forecast):
    if day_forecast['temperatureMax'] > 80:
        return "hot"
    elif day_forecast['temperatureMax'] > 70:
        return "warm"
    elif day_forecast['temperatureMax'] > 60:
        return "cool"
    elif day_forecast['temperatureMax'] < 33:
        return "freezing cold"

def rain_warning(day_forecast):
    if day_forecast['precipType'] == 'rain':
        return "Bring an umbrella."

def emailer(emailtxt):
	key = '##############'
	sandbox = '##########'
	recipient = '#############'
	
	request_url = 'https://api.mailgun.net/v2/{0}/messages'.format(sandbox)
	request = requests.post(request_url, auth=('api', key), data={
		'from': '##############',
		'to': recipient,
		'subject': 'Your daily weather info',
		'text': emailtxt
	})

weather_message = "Right now it is " \
	+ str(forecast['currently']['temperature']) \
	+ " degrees out and " \
	+ forecast['currently']['summary'].lower() + ".\n" \
	"Today will be " + \
	temp_feeling(forecast['daily']['data'][0]) + \
	" with a high of " + \
	str(forecast['daily']['data'][0]['temperatureMax']) + \
	" and a low of " + \
	str(forecast['daily']['data'][0]['temperatureMin']) + ". " + \
	rain_warning(forecast['daily']['data'][0])

print(weather_message)
# Out:
# Right now it is 80.58 degrees out and clear.
# Today will be hot with a high of 82.6 and a low of 66.31. Bring an umbrella.

# %%
pd.read_csv("nyt-data-2016-07-04-11-55.csv")
# Out:
#                                                 byline  \
# 0                                      By ERIC SCHMITT
# 1                                       By SCOTT SHANE
# 2                                     By JIM RUTENBERG
# 3                                     By ANNIE WALDMAN
# 4                                      By SHIVANI VORA
# 5                                        By SAM SIFTON
# 6                                       By SARAH LYALL
# 7                                                  NaN
# 8                                                  NaN
# 9                                       By ADAM LIPTAK
# 10                                    By DWIGHT GARNER
# 11   By JEFFREY GETTLEMAN and ISABEL KERSHNER 11:16...
# 12                                      By KATE MURPHY
# 13                              By EMMA G. FITZSIMMONS
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                 By SYLVIE KAUFFMANN
# 23                          By TAHMIMA ANAM 6:35 AM ET
# 24                                                 NaN
# 25                              By ROBERT G. PARKINSON
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 77                                                 NaN
# 78                                                 NaN
# 79                                                 NaN
# 80                                                 NaN
# 81                                                 NaN
# 82                                                 NaN
# 83                                                 NaN
# 84                                                 NaN
# 85                                                 NaN
# 86                                                 NaN
# 87                                                 NaN
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                        By DAN SHAW
# 104                                                NaN
# 105                                                NaN
# 106                                   By JULIE BESONEN
#
#                                               headline
# 0    As ISIS Loses Land, It Gains Ground in Statele...
# 1    Drone Data Shows Limits of Fighting Terror Fro...
# 2    When the Media Is Biased, and Doesn’t Try to H...
# 3    A Student Loan That Can’t Be Forgiven, Not Eve...
# 4                    How to Get Your Passport in Order
# 5              Our Best Recipes for the Fourth of July
# 6    ‘Brexit’ Upsets a London That Values Its Cultu...
# 7    Farage Resigns as Head of U.K. Independence Pa...
# 8    ‘Brexit’ Briefing: Mudslinging Among Conservat...
# 9    Sotomayor Takes on Criminal Justice System in ...
# 10   Garrison Keillor Turns Out the Lights on Lake ...
# 11   Netanyahu Traces Path to Power Back to Lost Br...
# 12          Why Tech Support Is (Purposely) Unbearable
# 13    New Jersey Savors Reprieve From Gas-Tax Increase
# 14   Australian Candidates Woo Allies Amid Deadlock...
# 15           Amazon Is Quietly Eliminating List Prices
# 16   Where ‘Not in My Backyard’ Prevails, Equality ...
# 17   Man Injured by Suspected Fireworks in Central ...
# 18   What Clinton’s First 100 Days in Office Might ...
# 19         Elie Wiesel, Nobel Prize Winner, Dies at 87
# 20     In ‘Bush,’ a Biography as a Scathing Indictment
# 21        A House That Love Built — Before It Was Gone
# 22                             Why Frexit Won’t Happen
# 23                          Horror and Sorrow in Dhaka
# 24                               Join us on Facebook »
# 25                               A Declaration of Fear
# 26            Editorial: An Exodus in Our Own Backyard
# 27                        Blow: Giving Clinton Her Due
# 28                   Krugman: Trump, Trade and Workers
# 29   Editorial: This Fourth of July, Proclaim a Bre...
# ..                                                 ...
# 77   Review: A Sweet Take on British Identity Retur...
# 78   Game of Thrones: In ‘Game of Thrones,’ the Ple...
# 79   The New Old Age: What Doctors Know About How B...
# 80          Well: A Call for Action on Toxic Chemicals
# 81                     36 Hours: 36 Hours in Cleveland
# 82   Frugal Traveler: 10 Free (or Cheap) Travel App...
# 83               ‘The Arrangements’: A Work of Fiction
# 84   Nonfiction: The Good, the True, the Beautiful ...
# 85   Wyoming Schools Look for a Middle Way for Tran...
# 86   A Sea of Charter Schools in Detroit Leaves Stu...
# 87             What to Cook: Recipes, Fireworks, Songs
# 88   City Kitchen: Spicy Cold Noodles Offer an Anti...
# 89   Editorial: How to Revive the Promise of the Eu...
# 90   Frank Bruni: The Utter Inconsequence of Hillar...
# 91                          Outdoor Decor: A Checklist
# 92   What I Love: Tamron Hall, of the ‘Today’ Show,...
# 93   Disunion: Why the European Union Could Break i...
# 94             The 2016 Race: How Polling Can Go Wrong
# 95           Feature: The Secrets in Guatemala’s Bones
# 96   Feature: How ‘Advantage Players’ Game the Casinos
# 97   Self-Driving Tesla Was Involved in Fatal Crash...
# 98   Driven: Video Review: Hyundai’s Plug-In Sonata...
# 99   Portraits of London Life (and its Many Subcult...
# 100    Two Summery Cocktail Recipes, One Handy New App
# 101  Insider Podcasts: Paul Krugman on ‘Brexit’ and...
# 102    An Irish-German-Chinese Perspective on ‘Brexit’
# 103  Tamron Hall, of the ‘Today’ Show, Feathers Her...
# 104                  Search for Homes for Sale or Rent
# 105                                     Sell Your Home
# 106     Gramercy Park: Steeped in History and Grandeur
#
# [107 rows x 2 columns]
